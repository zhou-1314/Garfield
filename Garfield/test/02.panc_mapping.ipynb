# %% [markdown]
# ### QueryToReference mapping

# %% [markdown]
# Here we will use human pancreas datasets (scRNA-seq data) of different studies as an example to illustrate how Garfield performs QueryToreference process.

# %%
import os
os.chdir('/data2/zhouwg_data/project/Garfield')
os.getcwd()
# Out:
# '/data2/zhouwg_data/project/Garfield'

# %%
# load packages
import warnings
import Garfield as gf
import scanpy as sc

warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

gf.__version__
# Out:
# '0.3.1'

# %%
## load data
adata = sc.read_h5ad('/home/zhouweige/zhouwg_data/project/Garfield_tutorials/data/panc8.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 14890 × 34363
#     obs: 'ClusterID', 'ClusterName', 'batch', 'celltype', 'nCount_RNA'
#     var: 'Selected', 'vst_mean', 'vst_variable', 'vst_variance', 'vst_variance_expected', 'vst_variance_standardized'
#     obsm: 'pca_cell_embeddings', 'umap_cell_embeddings'
#     varm: 'pca_feature_loadings'
#     layers: 'counts', 'norm_data', 'scale_data'

# %%
# Ensure adata.X is counts.
adata.X.max()
# Out:
# 1453667.0

# %%
# check the batch information of this dataset
adata.obs['batch'].value_counts()
# Out:
# batch
# indrop        8569
# smartseq2     2394
# celseq2       2285
# celseq        1004
# fluidigmc1     638
# Name: count, dtype: int64

# %% [markdown]
# ### split all_adata into reference dataset and query dataset

# %%
adata_ref = adata[~adata.obs['batch'].isin(['smartseq2', 'celseq2']),:]
adata_ref
# Out:
# View of AnnData object with n_obs × n_vars = 10211 × 34363
#     obs: 'ClusterID', 'ClusterName', 'batch', 'celltype', 'nCount_RNA'
#     var: 'Selected', 'vst_mean', 'vst_variable', 'vst_variance', 'vst_variance_expected', 'vst_variance_standardized'
#     obsm: 'pca_cell_embeddings', 'umap_cell_embeddings'
#     varm: 'pca_feature_loadings'
#     layers: 'counts', 'norm_data', 'scale_data'

# %%
# Inspect the batches contained in the dataset.
adata_ref.obs.batch.value_counts()
# Out:
# batch
# indrop        8569
# celseq        1004
# fluidigmc1     638
# Name: count, dtype: int64

# %%
adata_query = adata[adata.obs['batch'].isin(['smartseq2', 'celseq2']),:]
adata_query
# Out:
# View of AnnData object with n_obs × n_vars = 4679 × 34363
#     obs: 'ClusterID', 'ClusterName', 'batch', 'celltype', 'nCount_RNA'
#     var: 'Selected', 'vst_mean', 'vst_variable', 'vst_variance', 'vst_variance_expected', 'vst_variance_standardized'
#     obsm: 'pca_cell_embeddings', 'umap_cell_embeddings'
#     varm: 'pca_feature_loadings'
#     layers: 'counts', 'norm_data', 'scale_data'

# %%
# Inspect the batches contained in the dataset.
adata_query.obs.batch.value_counts()
# Out:
# batch
# smartseq2    2394
# celseq2      2285
# Name: count, dtype: int64

# %% [markdown]
# ## Integrating reference data using Garfield

# %% [markdown]
# For reference integration of scRNAseq data, we should adjust the following paremeters, and all parameter introductions can be found in [Garfield_Model_Parameters](https://github.com/zhou-1314/Garfield/blob/main/Garfield_Model_Parameters.md).

# %%
# set workdir
workdir = '/home/zhouweige/zhouwg_data/project/Garfield_tutorials/result/garfield_QueryToRef_panc' 
gf.settings.set_workdir(workdir)

### modify parameter
user_config = dict(
    ## Input options
    adata_list=adata, 
    profile='RNA',   # if it is 'ATAC' or 'ADT', please adjust it.
    sample_col='batch',  # Specify columns for batch

    ## Preprocessing options
    used_hvg=True,
    min_cells=3,
    min_features=0,
    keep_mt=False,
    target_sum=1e4,
    rna_n_top_features=3000,
    atac_n_top_features=None, # if data belongs to 'ATAC', please specify it.
    n_components=50,
    n_neighbors=5,
    metric='euclidean',  # STR     Metric for clustering.                   Default is `euclidean`.
    svd_solver='arpack',
    # datasets
    adj_key='connectivities',
    
    # data split parameters
    edge_val_ratio=0.1,
    edge_test_ratio=0.,
    node_val_ratio=0.1,
    node_test_ratio=0.,

    ## Model options
    augment_type='svd',
    svd_q=5,
    use_FCencoder=False,
    conv_type='GATv2Conv', # GAT or GATv2Conv or GCN
    gnn_layer=2,
    hidden_dims=[128, 128],
    bottle_neck_neurons=20,
    cluster_num=20,
    drop_feature_rate=0.2, 
    drop_edge_rate=0.2,
    num_heads=3,
    dropout=0.2,
    concat=True,
    used_edge_weight=False,
    used_DSBN=False,
    used_mmd=True,
    # data loader parameters
    num_neighbors=5,
    loaders_n_hops=2,
    edge_batch_size=4096,
    node_batch_size=128, # None
    # loss parameters
    include_edge_recon_loss=False,
    include_gene_expr_recon_loss=True,
    lambda_latent_contrastive_instanceloss=1.0,
    lambda_latent_contrastive_clusterloss=0.5,
    lambda_gene_expr_recon=500., # To make the model more focused on learning expression features, increase this parameter.
    lambda_edge_recon=100., # To make the model more focused on learning Adjacency graph features, increase this parameter.
    lambda_omics_recon_mmd_loss=3., # If the integration is not strong enough, increase it.
    # train parameters
    n_epochs_no_edge_recon=0,
    learning_rate=0.001,
    weight_decay=1e-05,
    gradient_clipping=5,
    # other parameters
    latent_key='garfield_latent',
    reload_best_model=True,
    use_early_stopping=True,
    early_stopping_kwargs=None,
    monitor=True,
    seed=2024,
    verbose=True
)
dict_config = gf.settings.set_gf_params(user_config)
# Out:
# Saving results in: /home/zhouweige/zhouwg_data/project/Garfield_tutorials/result/garfield_QueryToRef_panc

# %%
from Garfield.model import Garfield

# Initialize model
model = Garfield(dict_config)
# Out:
# --- DATA LOADING AND PREPROCESSING ---
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.2

# %%
# Train model
model.train()
# Out:
# --- INITIALIZING TRAINER ---
# Number of training nodes: 13401
# Number of validation nodes: 1489
# Number of training edges: 41904
# Number of validation edges: 4655
# Edge batch size: 4096
# Node batch size: 128
#
# --- MODEL TRAINING ---
# Epoch 1/100 |--------------------| 1.0% val_auroc_score: 0.8981; val_auprc_score: 0.8834; val_best_acc_score: 0.7988; val_best_f1_score: 0.8153; train_kl_reg_loss: 25.6854; train_edge_recon_loss: 70.5568; train_gene_expr_recon_loss: 71812.6950; train_lambda_latent_contrastive_instanceloss: 7.1768; train_lambda_latent_contrastive_clusterloss: 3.6995; train_gene_expr_mmd_loss: 8140.0272; train_global_loss: 79989.2841; train_optim_loss: 79989.2841; val_kl_reg_loss: 19.7598; val_edge_recon_loss: 76.5443; val_gene_expr_recon_loss: 61161.8887; val_lambda_latent_contrastive_instanceloss: 7.0860; val_lambda_latent_contrastive_clusterloss: 3.6555; val_gene_expr_mmd_loss: 10097.2271; val_global_loss: 71289.6172; val_optim_loss: 71289.6172
# Epoch 2/100 |--------------------| 2.0% val_auroc_score: 0.9269; val_auprc_score: 0.9108; val_best_acc_score: 0.8573; val_best_f1_score: 0.8585; train_kl_reg_loss: 29.4856; train_edge_recon_loss: 69.2312; train_gene_expr_recon_loss: 55135.4918; train_lambda_latent_contrastive_instanceloss: 7.1426; train_lambda_latent_contrastive_clusterloss: 3.6545; train_gene_expr_mmd_loss: 8845.4718; train_global_loss: 64021.2468; train_optim_loss: 64021.2468; val_kl_reg_loss: 27.6087; val_edge_recon_loss: 71.8362; val_gene_expr_recon_loss: 50026.3359; val_lambda_latent_contrastive_instanceloss: 6.9013; val_lambda_latent_contrastive_clusterloss: 3.6014; val_gene_expr_mmd_loss: 13437.8237; val_global_loss: 63502.2695; val_optim_loss: 63502.2695
# Epoch 3/100 |--------------------| 3.0% val_auroc_score: 0.9415; val_auprc_score: 0.9222; val_best_acc_score: 0.8820; val_best_f1_score: 0.8891; train_kl_reg_loss: 37.2182; train_edge_recon_loss: 69.3484; train_gene_expr_recon_loss: 48898.7752; train_lambda_latent_contrastive_instanceloss: 7.0988; train_lambda_latent_contrastive_clusterloss: 3.6351; train_gene_expr_mmd_loss: 8518.8161; train_global_loss: 57465.5430; train_optim_loss: 57465.5430; val_kl_reg_loss: 35.9097; val_edge_recon_loss: 74.9679; val_gene_expr_recon_loss: 44316.5000; val_lambda_latent_contrastive_instanceloss: 6.9183; val_lambda_latent_contrastive_clusterloss: 3.5871; val_gene_expr_mmd_loss: 16846.0117; val_global_loss: 61208.9277; val_optim_loss: 61208.9277
# Epoch 4/100 |--------------------| 4.0% val_auroc_score: 0.9413; val_auprc_score: 0.9214; val_best_acc_score: 0.8801; val_best_f1_score: 0.8912; train_kl_reg_loss: 50.8278; train_edge_recon_loss: 70.6725; train_gene_expr_recon_loss: 45586.8725; train_lambda_latent_contrastive_instanceloss: 7.0489; train_lambda_latent_contrastive_clusterloss: 3.6152; train_gene_expr_mmd_loss: 8134.8334; train_global_loss: 53783.1985; train_optim_loss: 53783.1985; val_kl_reg_loss: 51.7784; val_edge_recon_loss: 76.6626; val_gene_expr_recon_loss: 42435.8047; val_lambda_latent_contrastive_instanceloss: 6.7443; val_lambda_latent_contrastive_clusterloss: 3.5336; val_gene_expr_mmd_loss: 12618.8643; val_global_loss: 55116.7227; val_optim_loss: 55116.7227
# Epoch 5/100 |█-------------------| 5.0% val_auroc_score: 0.9518; val_auprc_score: 0.9359; val_best_acc_score: 0.8836; val_best_f1_score: 0.8945; train_kl_reg_loss: 62.0207; train_edge_recon_loss: 71.3775; train_gene_expr_recon_loss: 43987.3441; train_lambda_latent_contrastive_instanceloss: 6.9296; train_lambda_latent_contrastive_clusterloss: 3.5754; train_gene_expr_mmd_loss: 9638.3771; train_global_loss: 53698.2464; train_optim_loss: 53698.2464; val_kl_reg_loss: 50.9966; val_edge_recon_loss: 77.1321; val_gene_expr_recon_loss: 42275.2109; val_lambda_latent_contrastive_instanceloss: 6.5814; val_lambda_latent_contrastive_clusterloss: 3.4722; val_gene_expr_mmd_loss: 9255.1157; val_global_loss: 51591.3770; val_optim_loss: 51591.3770
# Epoch 6/100 |█-------------------| 6.0% val_auroc_score: 0.9508; val_auprc_score: 0.9363; val_best_acc_score: 0.8830; val_best_f1_score: 0.8944; train_kl_reg_loss: 61.9805; train_edge_recon_loss: 71.9359; train_gene_expr_recon_loss: 41962.0032; train_lambda_latent_contrastive_instanceloss: 6.8510; train_lambda_latent_contrastive_clusterloss: 3.5417; train_gene_expr_mmd_loss: 7724.5613; train_global_loss: 49758.9382; train_optim_loss: 49758.9382; val_kl_reg_loss: 56.4100; val_edge_recon_loss: 77.5529; val_gene_expr_recon_loss: 41011.1035; val_lambda_latent_contrastive_instanceloss: 6.4799; val_lambda_latent_contrastive_clusterloss: 3.3651; val_gene_expr_mmd_loss: 11681.3667; val_global_loss: 52758.7246; val_optim_loss: 52758.7246
# Epoch 7/100 |█-------------------| 7.0% val_auroc_score: 0.9411; val_auprc_score: 0.9239; val_best_acc_score: 0.8573; val_best_f1_score: 0.8743; train_kl_reg_loss: 69.4729; train_edge_recon_loss: 72.5547; train_gene_expr_recon_loss: 41295.8445; train_lambda_latent_contrastive_instanceloss: 6.7713; train_lambda_latent_contrastive_clusterloss: 3.4845; train_gene_expr_mmd_loss: 8254.1508; train_global_loss: 49629.7244; train_optim_loss: 49629.7244; val_kl_reg_loss: 63.2175; val_edge_recon_loss: 78.3030; val_gene_expr_recon_loss: 40859.3613; val_lambda_latent_contrastive_instanceloss: 6.4241; val_lambda_latent_contrastive_clusterloss: 3.2361; val_gene_expr_mmd_loss: 11309.1304; val_global_loss: 52241.3691; val_optim_loss: 52241.3691
# Epoch 8/100 |█-------------------| 8.0% val_auroc_score: 0.9448; val_auprc_score: 0.9255; val_best_acc_score: 0.8561; val_best_f1_score: 0.8737; train_kl_reg_loss: 75.4037; train_edge_recon_loss: 73.1834; train_gene_expr_recon_loss: 41780.5114; train_lambda_latent_contrastive_instanceloss: 6.7232; train_lambda_latent_contrastive_clusterloss: 3.4151; train_gene_expr_mmd_loss: 7187.7496; train_global_loss: 49053.8029; train_optim_loss: 49053.8029; val_kl_reg_loss: 62.2532; val_edge_recon_loss: 78.7095; val_gene_expr_recon_loss: 41315.0977; val_lambda_latent_contrastive_instanceloss: 6.4131; val_lambda_latent_contrastive_clusterloss: 3.1542; val_gene_expr_mmd_loss: 9970.7041; val_global_loss: 51357.6211; val_optim_loss: 51357.6211
# Epoch 9/100 |█-------------------| 9.0% val_auroc_score: 0.9494; val_auprc_score: 0.9320; val_best_acc_score: 0.8516; val_best_f1_score: 0.8703; train_kl_reg_loss: 73.9191; train_edge_recon_loss: 73.1674; train_gene_expr_recon_loss: 41673.0117; train_lambda_latent_contrastive_instanceloss: 6.6944; train_lambda_latent_contrastive_clusterloss: 3.3565; train_gene_expr_mmd_loss: 7492.5832; train_global_loss: 49249.5639; train_optim_loss: 49249.5639; val_kl_reg_loss: 69.3755; val_edge_recon_loss: 79.1857; val_gene_expr_recon_loss: 40597.2227; val_lambda_latent_contrastive_instanceloss: 6.3957; val_lambda_latent_contrastive_clusterloss: 3.0963; val_gene_expr_mmd_loss: 11270.2520; val_global_loss: 51946.3418; val_optim_loss: 51946.3418
# Epoch 10/100 |██------------------| 10.0% val_auroc_score: 0.9479; val_auprc_score: 0.9299; val_best_acc_score: 0.8392; val_best_f1_score: 0.8611; train_kl_reg_loss: 87.8189; train_edge_recon_loss: 73.8004; train_gene_expr_recon_loss: 40914.6126; train_lambda_latent_contrastive_instanceloss: 6.6620; train_lambda_latent_contrastive_clusterloss: 3.2914; train_gene_expr_mmd_loss: 6717.9988; train_global_loss: 47730.3842; train_optim_loss: 47730.3842; val_kl_reg_loss: 76.5639; val_edge_recon_loss: 79.1739; val_gene_expr_recon_loss: 42991.3477; val_lambda_latent_contrastive_instanceloss: 6.3959; val_lambda_latent_contrastive_clusterloss: 3.0174; val_gene_expr_mmd_loss: 11293.7549; val_global_loss: 54371.0801; val_optim_loss: 54371.0801
# Epoch 11/100 |██------------------| 11.0% val_auroc_score: 0.9532; val_auprc_score: 0.9359; val_best_acc_score: 0.8712; val_best_f1_score: 0.8856; train_kl_reg_loss: 90.4206; train_edge_recon_loss: 73.7244; train_gene_expr_recon_loss: 41175.6740; train_lambda_latent_contrastive_instanceloss: 6.6351; train_lambda_latent_contrastive_clusterloss: 3.2169; train_gene_expr_mmd_loss: 6407.9091; train_global_loss: 47683.8555; train_optim_loss: 47683.8555; val_kl_reg_loss: 76.9896; val_edge_recon_loss: 79.0326; val_gene_expr_recon_loss: 40481.7715; val_lambda_latent_contrastive_instanceloss: 6.4323; val_lambda_latent_contrastive_clusterloss: 2.9716; val_gene_expr_mmd_loss: 8418.8433; val_global_loss: 48987.0078; val_optim_loss: 48987.0078
# Epoch 12/100 |██------------------| 12.0% val_auroc_score: 0.9625; val_auprc_score: 0.9498; val_best_acc_score: 0.8905; val_best_f1_score: 0.9008; train_kl_reg_loss: 86.7575; train_edge_recon_loss: 73.5862; train_gene_expr_recon_loss: 39941.4790; train_lambda_latent_contrastive_instanceloss: 6.6364; train_lambda_latent_contrastive_clusterloss: 3.1612; train_gene_expr_mmd_loss: 6987.3556; train_global_loss: 47025.3896; train_optim_loss: 47025.3896; val_kl_reg_loss: 72.4219; val_edge_recon_loss: 78.4277; val_gene_expr_recon_loss: 40967.1895; val_lambda_latent_contrastive_instanceloss: 6.3855; val_lambda_latent_contrastive_clusterloss: 2.8710; val_gene_expr_mmd_loss: 10473.4180; val_global_loss: 51522.2871; val_optim_loss: 51522.2871
# Epoch 13/100 |██------------------| 13.0% val_auroc_score: 0.9663; val_auprc_score: 0.9510; val_best_acc_score: 0.8890; val_best_f1_score: 0.8998; train_kl_reg_loss: 84.1076; train_edge_recon_loss: 73.4235; train_gene_expr_recon_loss: 39819.1879; train_lambda_latent_contrastive_instanceloss: 6.6114; train_lambda_latent_contrastive_clusterloss: 3.0811; train_gene_expr_mmd_loss: 7803.2794; train_global_loss: 47716.2681; train_optim_loss: 47716.2681; val_kl_reg_loss: 74.6134; val_edge_recon_loss: 78.7437; val_gene_expr_recon_loss: 38971.5117; val_lambda_latent_contrastive_instanceloss: 6.3889; val_lambda_latent_contrastive_clusterloss: 2.8235; val_gene_expr_mmd_loss: 14602.8618; val_global_loss: 53658.2012; val_optim_loss: 53658.2012
# Epoch 14/100 |██------------------| 14.0% val_auroc_score: 0.9697; val_auprc_score: 0.9593; val_best_acc_score: 0.8863; val_best_f1_score: 0.8975; train_kl_reg_loss: 91.4341; train_edge_recon_loss: 73.5749; train_gene_expr_recon_loss: 39816.3803; train_lambda_latent_contrastive_instanceloss: 6.5846; train_lambda_latent_contrastive_clusterloss: 3.0149; train_gene_expr_mmd_loss: 10241.6203; train_global_loss: 50159.0334; train_optim_loss: 50159.0334; val_kl_reg_loss: 80.6057; val_edge_recon_loss: 78.8550; val_gene_expr_recon_loss: 39911.1406; val_lambda_latent_contrastive_instanceloss: 6.3783; val_lambda_latent_contrastive_clusterloss: 2.7670; val_gene_expr_mmd_loss: 10525.3379; val_global_loss: 50526.2266; val_optim_loss: 50526.2266
# Epoch 15/100 |███-----------------| 15.0% val_auroc_score: 0.9616; val_auprc_score: 0.9407; val_best_acc_score: 0.8806; val_best_f1_score: 0.8928; train_kl_reg_loss: 95.0650; train_edge_recon_loss: 73.8771; train_gene_expr_recon_loss: 38397.9020; train_lambda_latent_contrastive_instanceloss: 6.5710; train_lambda_latent_contrastive_clusterloss: 2.9782; train_gene_expr_mmd_loss: 7210.7792; train_global_loss: 45713.2951; train_optim_loss: 45713.2951; val_kl_reg_loss: 79.6664; val_edge_recon_loss: 78.9779; val_gene_expr_recon_loss: 38054.4746; val_lambda_latent_contrastive_instanceloss: 6.3726; val_lambda_latent_contrastive_clusterloss: 2.7511; val_gene_expr_mmd_loss: 9848.6597; val_global_loss: 47991.9277; val_optim_loss: 47991.9277
# Epoch 16/100 |███-----------------| 16.0% val_auroc_score: 0.9664; val_auprc_score: 0.9551; val_best_acc_score: 0.8710; val_best_f1_score: 0.8853; train_kl_reg_loss: 96.5127; train_edge_recon_loss: 73.9455; train_gene_expr_recon_loss: 39472.0795; train_lambda_latent_contrastive_instanceloss: 6.5894; train_lambda_latent_contrastive_clusterloss: 2.9531; train_gene_expr_mmd_loss: 7665.1541; train_global_loss: 47243.2901; train_optim_loss: 47243.2901; val_kl_reg_loss: 82.0880; val_edge_recon_loss: 79.0288; val_gene_expr_recon_loss: 38562.1152; val_lambda_latent_contrastive_instanceloss: 6.3886; val_lambda_latent_contrastive_clusterloss: 2.6972; val_gene_expr_mmd_loss: 9195.6633; val_global_loss: 47848.9512; val_optim_loss: 47848.9512
# Epoch 17/100 |███-----------------| 17.0% val_auroc_score: 0.9684; val_auprc_score: 0.9579; val_best_acc_score: 0.8646; val_best_f1_score: 0.8802; train_kl_reg_loss: 100.5117; train_edge_recon_loss: 74.0230; train_gene_expr_recon_loss: 38735.7646; train_lambda_latent_contrastive_instanceloss: 6.5613; train_lambda_latent_contrastive_clusterloss: 2.8855; train_gene_expr_mmd_loss: 7523.1344; train_global_loss: 46368.8562; train_optim_loss: 46368.8562; val_kl_reg_loss: 86.0734; val_edge_recon_loss: 78.9375; val_gene_expr_recon_loss: 39907.2871; val_lambda_latent_contrastive_instanceloss: 6.4037; val_lambda_latent_contrastive_clusterloss: 2.7030; val_gene_expr_mmd_loss: 9369.2935; val_global_loss: 49371.7617; val_optim_loss: 49371.7617
# Epoch 18/100 |███-----------------| 18.0% val_auroc_score: 0.9700; val_auprc_score: 0.9601; val_best_acc_score: 0.8800; val_best_f1_score: 0.8923; train_kl_reg_loss: 99.7555; train_edge_recon_loss: 73.8758; train_gene_expr_recon_loss: 38092.6964; train_lambda_latent_contrastive_instanceloss: 6.5591; train_lambda_latent_contrastive_clusterloss: 2.8691; train_gene_expr_mmd_loss: 7606.8718; train_global_loss: 45808.7518; train_optim_loss: 45808.7518; val_kl_reg_loss: 83.7028; val_edge_recon_loss: 78.8417; val_gene_expr_recon_loss: 37752.6406; val_lambda_latent_contrastive_instanceloss: 6.3744; val_lambda_latent_contrastive_clusterloss: 2.6414; val_gene_expr_mmd_loss: 10217.4863; val_global_loss: 48062.8438; val_optim_loss: 48062.8438
# Epoch 19/100 |███-----------------| 19.0% val_auroc_score: 0.9690; val_auprc_score: 0.9598; val_best_acc_score: 0.8840; val_best_f1_score: 0.8954; train_kl_reg_loss: 100.7309; train_edge_recon_loss: 73.8526; train_gene_expr_recon_loss: 37544.8487; train_lambda_latent_contrastive_instanceloss: 6.5469; train_lambda_latent_contrastive_clusterloss: 2.8468; train_gene_expr_mmd_loss: 7309.6393; train_global_loss: 44964.6129; train_optim_loss: 44964.6129; val_kl_reg_loss: 81.6539; val_edge_recon_loss: 78.7410; val_gene_expr_recon_loss: 38063.4688; val_lambda_latent_contrastive_instanceloss: 6.3741; val_lambda_latent_contrastive_clusterloss: 2.6323; val_gene_expr_mmd_loss: 9774.2441; val_global_loss: 47928.3711; val_optim_loss: 47928.3711
# Epoch 20/100 |████----------------| 20.0% val_auroc_score: 0.9730; val_auprc_score: 0.9650; val_best_acc_score: 0.8802; val_best_f1_score: 0.8927; train_kl_reg_loss: 101.0974; train_edge_recon_loss: 73.8463; train_gene_expr_recon_loss: 38620.9357; train_lambda_latent_contrastive_instanceloss: 6.5467; train_lambda_latent_contrastive_clusterloss: 2.8189; train_gene_expr_mmd_loss: 6791.8834; train_global_loss: 45523.2820; train_optim_loss: 45523.2820; val_kl_reg_loss: 87.7954; val_edge_recon_loss: 78.8298; val_gene_expr_recon_loss: 38664.3965; val_lambda_latent_contrastive_instanceloss: 6.3788; val_lambda_latent_contrastive_clusterloss: 2.6222; val_gene_expr_mmd_loss: 9357.8281; val_global_loss: 48119.0234; val_optim_loss: 48119.0234
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 4 epochs.
# New learning rate is 0.0001.
#
# Epoch 21/100 |████----------------| 21.0% val_auroc_score: 0.9702; val_auprc_score: 0.9601; val_best_acc_score: 0.8676; val_best_f1_score: 0.8826; train_kl_reg_loss: 106.3935; train_edge_recon_loss: 74.0105; train_gene_expr_recon_loss: 37164.1697; train_lambda_latent_contrastive_instanceloss: 6.5330; train_lambda_latent_contrastive_clusterloss: 2.8113; train_gene_expr_mmd_loss: 6854.6961; train_global_loss: 44134.6030; train_optim_loss: 44134.6030; val_kl_reg_loss: 86.5095; val_edge_recon_loss: 78.9082; val_gene_expr_recon_loss: 37961.2754; val_lambda_latent_contrastive_instanceloss: 6.3834; val_lambda_latent_contrastive_clusterloss: 2.6363; val_gene_expr_mmd_loss: 8437.4199; val_global_loss: 46494.2246; val_optim_loss: 46494.2246
# Epoch 22/100 |████----------------| 22.0% val_auroc_score: 0.9693; val_auprc_score: 0.9600; val_best_acc_score: 0.8750; val_best_f1_score: 0.8885; train_kl_reg_loss: 105.1112; train_edge_recon_loss: 74.0518; train_gene_expr_recon_loss: 37546.2997; train_lambda_latent_contrastive_instanceloss: 6.5322; train_lambda_latent_contrastive_clusterloss: 2.8047; train_gene_expr_mmd_loss: 7179.1493; train_global_loss: 44839.8960; train_optim_loss: 44839.8960; val_kl_reg_loss: 87.0762; val_edge_recon_loss: 78.9992; val_gene_expr_recon_loss: 38527.7676; val_lambda_latent_contrastive_instanceloss: 6.3679; val_lambda_latent_contrastive_clusterloss: 2.6204; val_gene_expr_mmd_loss: 10302.1753; val_global_loss: 48926.0039; val_optim_loss: 48926.0039
# Epoch 23/100 |████----------------| 23.0% val_auroc_score: 0.9726; val_auprc_score: 0.9638; val_best_acc_score: 0.8743; val_best_f1_score: 0.8880; train_kl_reg_loss: 106.8440; train_edge_recon_loss: 74.0845; train_gene_expr_recon_loss: 37154.3072; train_lambda_latent_contrastive_instanceloss: 6.5180; train_lambda_latent_contrastive_clusterloss: 2.7809; train_gene_expr_mmd_loss: 8016.6323; train_global_loss: 45287.0820; train_optim_loss: 45287.0820; val_kl_reg_loss: 89.0435; val_edge_recon_loss: 78.8841; val_gene_expr_recon_loss: 36407.2031; val_lambda_latent_contrastive_instanceloss: 6.3584; val_lambda_latent_contrastive_clusterloss: 2.6154; val_gene_expr_mmd_loss: 9879.5259; val_global_loss: 46384.7441; val_optim_loss: 46384.7441
# Epoch 24/100 |████----------------| 24.0% val_auroc_score: 0.9725; val_auprc_score: 0.9622; val_best_acc_score: 0.8690; val_best_f1_score: 0.8837; train_kl_reg_loss: 108.1150; train_edge_recon_loss: 74.1358; train_gene_expr_recon_loss: 37909.8551; train_lambda_latent_contrastive_instanceloss: 6.5241; train_lambda_latent_contrastive_clusterloss: 2.7798; train_gene_expr_mmd_loss: 6344.4055; train_global_loss: 44371.6790; train_optim_loss: 44371.6790; val_kl_reg_loss: 88.9446; val_edge_recon_loss: 78.9551; val_gene_expr_recon_loss: 38399.1543; val_lambda_latent_contrastive_instanceloss: 6.3580; val_lambda_latent_contrastive_clusterloss: 2.6029; val_gene_expr_mmd_loss: 9013.1357; val_global_loss: 47510.1934; val_optim_loss: 47510.1934
# Epoch 25/100 |█████---------------| 25.0% val_auroc_score: 0.9717; val_auprc_score: 0.9598; val_best_acc_score: 0.8721; val_best_f1_score: 0.8861; train_kl_reg_loss: 108.1730; train_edge_recon_loss: 74.1846; train_gene_expr_recon_loss: 36911.1314; train_lambda_latent_contrastive_instanceloss: 6.5308; train_lambda_latent_contrastive_clusterloss: 2.7976; train_gene_expr_mmd_loss: 6336.1662; train_global_loss: 43364.7990; train_optim_loss: 43364.7990; val_kl_reg_loss: 89.6087; val_edge_recon_loss: 78.9504; val_gene_expr_recon_loss: 38001.5039; val_lambda_latent_contrastive_instanceloss: 6.3836; val_lambda_latent_contrastive_clusterloss: 2.6526; val_gene_expr_mmd_loss: 8297.6287; val_global_loss: 46397.7754; val_optim_loss: 46397.7754
# Epoch 26/100 |█████---------------| 26.0% val_auroc_score: 0.9736; val_auprc_score: 0.9658; val_best_acc_score: 0.8750; val_best_f1_score: 0.8884; train_kl_reg_loss: 107.9738; train_edge_recon_loss: 74.1432; train_gene_expr_recon_loss: 37504.0554; train_lambda_latent_contrastive_instanceloss: 6.5290; train_lambda_latent_contrastive_clusterloss: 2.7849; train_gene_expr_mmd_loss: 6285.7931; train_global_loss: 43907.1353; train_optim_loss: 43907.1353; val_kl_reg_loss: 88.5823; val_edge_recon_loss: 78.8592; val_gene_expr_recon_loss: 37458.2578; val_lambda_latent_contrastive_instanceloss: 6.3604; val_lambda_latent_contrastive_clusterloss: 2.6124; val_gene_expr_mmd_loss: 9596.4570; val_global_loss: 47152.2695; val_optim_loss: 47152.2695
# Epoch 27/100 |█████---------------| 27.0% val_auroc_score: 0.9725; val_auprc_score: 0.9595; val_best_acc_score: 0.8780; val_best_f1_score: 0.8909; train_kl_reg_loss: 108.3685; train_edge_recon_loss: 74.1193; train_gene_expr_recon_loss: 37188.6726; train_lambda_latent_contrastive_instanceloss: 6.5200; train_lambda_latent_contrastive_clusterloss: 2.7825; train_gene_expr_mmd_loss: 7070.8718; train_global_loss: 44377.2156; train_optim_loss: 44377.2156; val_kl_reg_loss: 89.6313; val_edge_recon_loss: 78.8730; val_gene_expr_recon_loss: 38002.3164; val_lambda_latent_contrastive_instanceloss: 6.3637; val_lambda_latent_contrastive_clusterloss: 2.5994; val_gene_expr_mmd_loss: 8166.6831; val_global_loss: 46267.5918; val_optim_loss: 46267.5918
# Epoch 28/100 |█████---------------| 28.0% val_auroc_score: 0.9708; val_auprc_score: 0.9597; val_best_acc_score: 0.8723; val_best_f1_score: 0.8863; train_kl_reg_loss: 108.1936; train_edge_recon_loss: 74.1887; train_gene_expr_recon_loss: 37382.5952; train_lambda_latent_contrastive_instanceloss: 6.5210; train_lambda_latent_contrastive_clusterloss: 2.7725; train_gene_expr_mmd_loss: 6164.6002; train_global_loss: 43664.6822; train_optim_loss: 43664.6822; val_kl_reg_loss: 89.6063; val_edge_recon_loss: 78.9460; val_gene_expr_recon_loss: 36989.5020; val_lambda_latent_contrastive_instanceloss: 6.3437; val_lambda_latent_contrastive_clusterloss: 2.6005; val_gene_expr_mmd_loss: 8701.5767; val_global_loss: 45789.6328; val_optim_loss: 45789.6328
# Epoch 29/100 |█████---------------| 29.0% val_auroc_score: 0.9711; val_auprc_score: 0.9567; val_best_acc_score: 0.8778; val_best_f1_score: 0.8907; train_kl_reg_loss: 109.3817; train_edge_recon_loss: 74.1899; train_gene_expr_recon_loss: 36731.0611; train_lambda_latent_contrastive_instanceloss: 6.5172; train_lambda_latent_contrastive_clusterloss: 2.7748; train_gene_expr_mmd_loss: 6767.9006; train_global_loss: 43617.6353; train_optim_loss: 43617.6353; val_kl_reg_loss: 91.7504; val_edge_recon_loss: 78.9705; val_gene_expr_recon_loss: 36991.6602; val_lambda_latent_contrastive_instanceloss: 6.3450; val_lambda_latent_contrastive_clusterloss: 2.5956; val_gene_expr_mmd_loss: 8502.5488; val_global_loss: 45594.9004; val_optim_loss: 45594.9004
# Epoch 30/100 |██████--------------| 30.0% val_auroc_score: 0.9698; val_auprc_score: 0.9573; val_best_acc_score: 0.8598; val_best_f1_score: 0.8766; train_kl_reg_loss: 112.1969; train_edge_recon_loss: 74.2202; train_gene_expr_recon_loss: 36653.5476; train_lambda_latent_contrastive_instanceloss: 6.5141; train_lambda_latent_contrastive_clusterloss: 2.7741; train_gene_expr_mmd_loss: 6823.0755; train_global_loss: 43598.1087; train_optim_loss: 43598.1087; val_kl_reg_loss: 92.5542; val_edge_recon_loss: 79.1164; val_gene_expr_recon_loss: 38965.9043; val_lambda_latent_contrastive_instanceloss: 6.3558; val_lambda_latent_contrastive_clusterloss: 2.6015; val_gene_expr_mmd_loss: 8452.7361; val_global_loss: 47520.1523; val_optim_loss: 47520.1523
# Epoch 31/100 |██████--------------| 31.0% val_auroc_score: 0.9717; val_auprc_score: 0.9627; val_best_acc_score: 0.8609; val_best_f1_score: 0.8775; train_kl_reg_loss: 112.2101; train_edge_recon_loss: 74.2865; train_gene_expr_recon_loss: 37137.5373; train_lambda_latent_contrastive_instanceloss: 6.5087; train_lambda_latent_contrastive_clusterloss: 2.7754; train_gene_expr_mmd_loss: 6329.5580; train_global_loss: 43588.5888; train_optim_loss: 43588.5888; val_kl_reg_loss: 93.4512; val_edge_recon_loss: 79.1689; val_gene_expr_recon_loss: 37381.7988; val_lambda_latent_contrastive_instanceloss: 6.3821; val_lambda_latent_contrastive_clusterloss: 2.6471; val_gene_expr_mmd_loss: 10123.2334; val_global_loss: 47607.5098; val_optim_loss: 47607.5098
# Epoch 32/100 |██████--------------| 32.0% val_auroc_score: 0.9770; val_auprc_score: 0.9693; val_best_acc_score: 0.8743; val_best_f1_score: 0.8880; train_kl_reg_loss: 112.6231; train_edge_recon_loss: 74.3161; train_gene_expr_recon_loss: 36798.8995; train_lambda_latent_contrastive_instanceloss: 6.5108; train_lambda_latent_contrastive_clusterloss: 2.7664; train_gene_expr_mmd_loss: 6958.1677; train_global_loss: 43878.9684; train_optim_loss: 43878.9684; val_kl_reg_loss: 93.6610; val_edge_recon_loss: 79.0065; val_gene_expr_recon_loss: 38225.9922; val_lambda_latent_contrastive_instanceloss: 6.3604; val_lambda_latent_contrastive_clusterloss: 2.5922; val_gene_expr_mmd_loss: 7716.8438; val_global_loss: 46045.4512; val_optim_loss: 46045.4512
# Epoch 33/100 |██████--------------| 33.0% val_auroc_score: 0.9726; val_auprc_score: 0.9602; val_best_acc_score: 0.8725; val_best_f1_score: 0.8865; train_kl_reg_loss: 111.9258; train_edge_recon_loss: 74.3316; train_gene_expr_recon_loss: 36938.7905; train_lambda_latent_contrastive_instanceloss: 6.5099; train_lambda_latent_contrastive_clusterloss: 2.7651; train_gene_expr_mmd_loss: 6532.8425; train_global_loss: 43592.8324; train_optim_loss: 43592.8324; val_kl_reg_loss: 92.4653; val_edge_recon_loss: 79.0551; val_gene_expr_recon_loss: 37146.1992; val_lambda_latent_contrastive_instanceloss: 6.3480; val_lambda_latent_contrastive_clusterloss: 2.6018; val_gene_expr_mmd_loss: 8744.5957; val_global_loss: 45992.2090; val_optim_loss: 45992.2090
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 4 epochs.
# New learning rate is 1e-05.
#
# Epoch 34/100 |██████--------------| 34.0% val_auroc_score: 0.9726; val_auprc_score: 0.9645; val_best_acc_score: 0.8656; val_best_f1_score: 0.8811; train_kl_reg_loss: 111.3593; train_edge_recon_loss: 74.2608; train_gene_expr_recon_loss: 36317.0870; train_lambda_latent_contrastive_instanceloss: 6.5215; train_lambda_latent_contrastive_clusterloss: 2.7868; train_gene_expr_mmd_loss: 6732.5548; train_global_loss: 43170.3086; train_optim_loss: 43170.3086; val_kl_reg_loss: 92.4582; val_edge_recon_loss: 79.1356; val_gene_expr_recon_loss: 36628.8730; val_lambda_latent_contrastive_instanceloss: 6.3613; val_lambda_latent_contrastive_clusterloss: 2.6032; val_gene_expr_mmd_loss: 7912.6384; val_global_loss: 44642.9316; val_optim_loss: 44642.9316
# Epoch 35/100 |███████-------------| 35.0% val_auroc_score: 0.9736; val_auprc_score: 0.9635; val_best_acc_score: 0.8709; val_best_f1_score: 0.8853; train_kl_reg_loss: 111.2437; train_edge_recon_loss: 74.3039; train_gene_expr_recon_loss: 36764.8192; train_lambda_latent_contrastive_instanceloss: 6.5087; train_lambda_latent_contrastive_clusterloss: 2.7622; train_gene_expr_mmd_loss: 7468.2561; train_global_loss: 44353.5902; train_optim_loss: 44353.5902; val_kl_reg_loss: 92.2553; val_edge_recon_loss: 79.1197; val_gene_expr_recon_loss: 36728.8242; val_lambda_latent_contrastive_instanceloss: 6.3623; val_lambda_latent_contrastive_clusterloss: 2.6094; val_gene_expr_mmd_loss: 8059.5583; val_global_loss: 44889.6094; val_optim_loss: 44889.6094
# Epoch 36/100 |███████-------------| 36.0% val_auroc_score: 0.9714; val_auprc_score: 0.9604; val_best_acc_score: 0.8617; val_best_f1_score: 0.8781; train_kl_reg_loss: 111.9819; train_edge_recon_loss: 74.3763; train_gene_expr_recon_loss: 36619.0579; train_lambda_latent_contrastive_instanceloss: 6.5173; train_lambda_latent_contrastive_clusterloss: 2.7756; train_gene_expr_mmd_loss: 6003.3236; train_global_loss: 42743.6562; train_optim_loss: 42743.6562; val_kl_reg_loss: 92.7556; val_edge_recon_loss: 79.1632; val_gene_expr_recon_loss: 37884.3613; val_lambda_latent_contrastive_instanceloss: 6.3457; val_lambda_latent_contrastive_clusterloss: 2.5790; val_gene_expr_mmd_loss: 8128.8511; val_global_loss: 46114.8926; val_optim_loss: 46114.8926
# Epoch 37/100 |███████-------------| 37.0% val_auroc_score: 0.9749; val_auprc_score: 0.9658; val_best_acc_score: 0.8700; val_best_f1_score: 0.8846; train_kl_reg_loss: 111.9373; train_edge_recon_loss: 74.3371; train_gene_expr_recon_loss: 36910.2024; train_lambda_latent_contrastive_instanceloss: 6.5017; train_lambda_latent_contrastive_clusterloss: 2.7549; train_gene_expr_mmd_loss: 7545.1842; train_global_loss: 44576.5803; train_optim_loss: 44576.5803; val_kl_reg_loss: 92.4833; val_edge_recon_loss: 79.0948; val_gene_expr_recon_loss: 35967.0312; val_lambda_latent_contrastive_instanceloss: 6.3722; val_lambda_latent_contrastive_clusterloss: 2.6266; val_gene_expr_mmd_loss: 7508.1335; val_global_loss: 43576.6465; val_optim_loss: 43576.6465
# Epoch 38/100 |███████-------------| 38.0% val_auroc_score: 0.9705; val_auprc_score: 0.9588; val_best_acc_score: 0.8650; val_best_f1_score: 0.8806; train_kl_reg_loss: 112.3466; train_edge_recon_loss: 74.2996; train_gene_expr_recon_loss: 36918.4165; train_lambda_latent_contrastive_instanceloss: 6.5035; train_lambda_latent_contrastive_clusterloss: 2.7505; train_gene_expr_mmd_loss: 7917.4193; train_global_loss: 44957.4361; train_optim_loss: 44957.4361; val_kl_reg_loss: 92.6266; val_edge_recon_loss: 79.0969; val_gene_expr_recon_loss: 37030.6934; val_lambda_latent_contrastive_instanceloss: 6.3763; val_lambda_latent_contrastive_clusterloss: 2.6097; val_gene_expr_mmd_loss: 8009.9585; val_global_loss: 45142.2656; val_optim_loss: 45142.2656
# Epoch 39/100 |███████-------------| 39.0% val_auroc_score: 0.9698; val_auprc_score: 0.9535; val_best_acc_score: 0.8661; val_best_f1_score: 0.8815; train_kl_reg_loss: 112.5759; train_edge_recon_loss: 74.3467; train_gene_expr_recon_loss: 36684.8583; train_lambda_latent_contrastive_instanceloss: 6.5198; train_lambda_latent_contrastive_clusterloss: 2.7804; train_gene_expr_mmd_loss: 6968.7049; train_global_loss: 43775.4382; train_optim_loss: 43775.4382; val_kl_reg_loss: 92.5313; val_edge_recon_loss: 79.2136; val_gene_expr_recon_loss: 35984.9688; val_lambda_latent_contrastive_instanceloss: 6.3524; val_lambda_latent_contrastive_clusterloss: 2.6163; val_gene_expr_mmd_loss: 8953.4590; val_global_loss: 45039.9258; val_optim_loss: 45039.9258
# Epoch 40/100 |████████------------| 40.0% val_auroc_score: 0.9712; val_auprc_score: 0.9585; val_best_acc_score: 0.8686; val_best_f1_score: 0.8835; train_kl_reg_loss: 112.0964; train_edge_recon_loss: 74.3996; train_gene_expr_recon_loss: 36580.1442; train_lambda_latent_contrastive_instanceloss: 6.5167; train_lambda_latent_contrastive_clusterloss: 2.7757; train_gene_expr_mmd_loss: 6554.5364; train_global_loss: 43256.0703; train_optim_loss: 43256.0703; val_kl_reg_loss: 92.9614; val_edge_recon_loss: 79.0556; val_gene_expr_recon_loss: 38098.8652; val_lambda_latent_contrastive_instanceloss: 6.3614; val_lambda_latent_contrastive_clusterloss: 2.5914; val_gene_expr_mmd_loss: 8193.4717; val_global_loss: 46394.2500; val_optim_loss: 46394.2500
# Epoch 41/100 |████████------------| 41.0% val_auroc_score: 0.9704; val_auprc_score: 0.9556; val_best_acc_score: 0.8642; val_best_f1_score: 0.8801; train_kl_reg_loss: 112.7902; train_edge_recon_loss: 74.3099; train_gene_expr_recon_loss: 36619.0877; train_lambda_latent_contrastive_instanceloss: 6.5069; train_lambda_latent_contrastive_clusterloss: 2.7653; train_gene_expr_mmd_loss: 6320.6313; train_global_loss: 43061.7827; train_optim_loss: 43061.7827; val_kl_reg_loss: 93.4718; val_edge_recon_loss: 79.1380; val_gene_expr_recon_loss: 37582.8125; val_lambda_latent_contrastive_instanceloss: 6.3580; val_lambda_latent_contrastive_clusterloss: 2.6010; val_gene_expr_mmd_loss: 9182.8809; val_global_loss: 46868.1250; val_optim_loss: 46868.1250
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 4 epochs.
# New learning rate is 1.0000000000000002e-06.
#
# Epoch 42/100 |████████------------| 42.0% val_auroc_score: 0.9695; val_auprc_score: 0.9584; val_best_acc_score: 0.8639; val_best_f1_score: 0.8798; train_kl_reg_loss: 113.3813; train_edge_recon_loss: 74.3460; train_gene_expr_recon_loss: 36288.4876; train_lambda_latent_contrastive_instanceloss: 6.5070; train_lambda_latent_contrastive_clusterloss: 2.7617; train_gene_expr_mmd_loss: 6906.4364; train_global_loss: 43317.5746; train_optim_loss: 43317.5746; val_kl_reg_loss: 93.6894; val_edge_recon_loss: 79.1608; val_gene_expr_recon_loss: 39067.0703; val_lambda_latent_contrastive_instanceloss: 6.3639; val_lambda_latent_contrastive_clusterloss: 2.5865; val_gene_expr_mmd_loss: 7569.7024; val_global_loss: 46739.4121; val_optim_loss: 46739.4121
# Epoch 43/100 |████████------------| 43.0% val_auroc_score: 0.9726; val_auprc_score: 0.9611; val_best_acc_score: 0.8632; val_best_f1_score: 0.8792; train_kl_reg_loss: 112.4108; train_edge_recon_loss: 74.3363; train_gene_expr_recon_loss: 36585.5305; train_lambda_latent_contrastive_instanceloss: 6.4993; train_lambda_latent_contrastive_clusterloss: 2.7548; train_gene_expr_mmd_loss: 6426.9339; train_global_loss: 43134.1296; train_optim_loss: 43134.1296; val_kl_reg_loss: 93.3597; val_edge_recon_loss: 79.1588; val_gene_expr_recon_loss: 37772.4141; val_lambda_latent_contrastive_instanceloss: 6.3582; val_lambda_latent_contrastive_clusterloss: 2.5947; val_gene_expr_mmd_loss: 8705.6902; val_global_loss: 46580.4141; val_optim_loss: 46580.4141
# Epoch 44/100 |████████------------| 44.0% val_auroc_score: 0.9736; val_auprc_score: 0.9646; val_best_acc_score: 0.8619; val_best_f1_score: 0.8782; train_kl_reg_loss: 112.8022; train_edge_recon_loss: 74.3428; train_gene_expr_recon_loss: 37400.3601; train_lambda_latent_contrastive_instanceloss: 6.5139; train_lambda_latent_contrastive_clusterloss: 2.7605; train_gene_expr_mmd_loss: 7468.4634; train_global_loss: 44990.8999; train_optim_loss: 44990.8999; val_kl_reg_loss: 93.0910; val_edge_recon_loss: 79.1229; val_gene_expr_recon_loss: 38471.7539; val_lambda_latent_contrastive_instanceloss: 6.3607; val_lambda_latent_contrastive_clusterloss: 2.6047; val_gene_expr_mmd_loss: 14417.6643; val_global_loss: 52991.4766; val_optim_loss: 52991.4766
# Epoch 45/100 |█████████-----------| 45.0% val_auroc_score: 0.9711; val_auprc_score: 0.9572; val_best_acc_score: 0.8635; val_best_f1_score: 0.8795; train_kl_reg_loss: 112.9180; train_edge_recon_loss: 74.3804; train_gene_expr_recon_loss: 36301.0916; train_lambda_latent_contrastive_instanceloss: 6.5093; train_lambda_latent_contrastive_clusterloss: 2.7690; train_gene_expr_mmd_loss: 5904.6264; train_global_loss: 42327.9144; train_optim_loss: 42327.9144; val_kl_reg_loss: 92.5866; val_edge_recon_loss: 79.1247; val_gene_expr_recon_loss: 37811.4395; val_lambda_latent_contrastive_instanceloss: 6.3738; val_lambda_latent_contrastive_clusterloss: 2.6136; val_gene_expr_mmd_loss: 8613.7104; val_global_loss: 46526.7266; val_optim_loss: 46526.7266
#
# Stopping early: metric has not improved more than 0.0 in the last 8 epochs.
# If the early stopping criterion is too strong, please instantiate it with different parameters in the train method.
# Model training finished after 3 min 2 sec.
# Using best model state, which was in epoch 37.
#
# --- MODEL EVALUATION ---
# val AUROC score: 0.9729
# val AUPRC score: 0.9612
# val best accuracy score: 0.8679
# val best F1 score: 0.8829
# val MSE score: 0.1136

# %%
# Compute latent neighbor graph
latent_key = 'garfield_latent'
sc.pp.neighbors(model.adata,
                use_rep=latent_key,
                key_added=latent_key)
# Compute UMAP embedding
sc.tl.umap(model.adata,
           neighbors_key=latent_key)

# %%
sc.pl.umap(model.adata, color=['batch', 'celltype'], wspace=0.35, edges=False)

# %%
# Save trained model
model_folder_path = f"{workdir}/model"
os.makedirs(model_folder_path, exist_ok=True)

model.save(dir_path=model_folder_path,
           overwrite=True,
           save_adata=True,
           adata_file_name="adata_ref.h5ad")

# %% [markdown]
# ## Perform surgery on reference model and fine-tune on query dataset

# %%
# load_query_data
new_model = model.load_query_data(dir_path=model_folder_path,
                                      query_adata=adata_query,
                                      ref_adata_name="adata_ref.h5ad",
                                      use_cuda=True,
                                      unfreeze_all_weights=False,
                                      unfreeze_eps_weight=True,
                                      unfreeze_layer0=True,
                                      used_mmd=True)
# Training and obtain latent representation
new_model.train()
# Out:
# WARNING:Garfield.model.utils:WARNING: Query shares 8.7303% of its genes with the reference.This may lead to inaccuracy in the results.
# Query data contains expression data of  31363  genes that were not contained in the reference dataset. This information will be removed from the query data object for further processing.
# AnnData object with n_obs × n_vars = 4679 × 3000
#     obs: 'ClusterID', 'ClusterName', 'batch', 'celltype', 'nCount_RNA'
#     var: 'Selected', 'vst_mean', 'vst_variable', 'vst_variance', 'vst_variance_expected', 'vst_variance_standardized'
#     obsm: 'pca_cell_embeddings', 'umap_cell_embeddings'
#     varm: 'pca_feature_loadings'
#     layers: 'counts', 'norm_data', 'scale_data'
# --- DATA LOADING AND PREPROCESSING ---
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.2
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 17612
# Number of validation nodes: 1957
# Number of training edges: 50931
# Number of validation edges: 5659
# Edge batch size: 4096
# Node batch size: 128
#
# --- MODEL TRAINING ---
# Epoch 1/100 |--------------------| 1.0% val_auroc_score: 0.9716; val_auprc_score: 0.9644; val_best_acc_score: 0.8465; val_best_f1_score: 0.8664; train_kl_reg_loss: 203.4007; train_edge_recon_loss: 74.9340; train_gene_expr_recon_loss: 100795.8203; train_lambda_latent_contrastive_instanceloss: 6.4710; train_lambda_latent_contrastive_clusterloss: 2.7626; train_gene_expr_mmd_loss: 10802.8657; train_global_loss: 111811.3209; train_optim_loss: 111811.3209; val_kl_reg_loss: 158.7246; val_edge_recon_loss: 79.2255; val_gene_expr_recon_loss: 97736.5586; val_lambda_latent_contrastive_instanceloss: 6.3416; val_lambda_latent_contrastive_clusterloss: 2.6508; val_gene_expr_mmd_loss: 10200.8848; val_global_loss: 108105.1602; val_optim_loss: 108105.1602
# Epoch 2/100 |--------------------| 2.0% val_auroc_score: 0.9717; val_auprc_score: 0.9617; val_best_acc_score: 0.8849; val_best_f1_score: 0.8962; train_kl_reg_loss: 186.4946; train_edge_recon_loss: 74.8038; train_gene_expr_recon_loss: 98261.7049; train_lambda_latent_contrastive_instanceloss: 6.4753; train_lambda_latent_contrastive_clusterloss: 2.7551; train_gene_expr_mmd_loss: 10324.5240; train_global_loss: 108781.9525; train_optim_loss: 108781.9525; val_kl_reg_loss: 149.8807; val_edge_recon_loss: 79.1207; val_gene_expr_recon_loss: 102907.8203; val_lambda_latent_contrastive_instanceloss: 6.3825; val_lambda_latent_contrastive_clusterloss: 2.6667; val_gene_expr_mmd_loss: 12210.4160; val_global_loss: 115277.1641; val_optim_loss: 115277.1641
# Epoch 3/100 |--------------------| 3.0% val_auroc_score: 0.9747; val_auprc_score: 0.9677; val_best_acc_score: 0.8981; val_best_f1_score: 0.9068; train_kl_reg_loss: 182.0446; train_edge_recon_loss: 74.7015; train_gene_expr_recon_loss: 95284.3395; train_lambda_latent_contrastive_instanceloss: 6.4671; train_lambda_latent_contrastive_clusterloss: 2.7518; train_gene_expr_mmd_loss: 10478.0387; train_global_loss: 105953.6418; train_optim_loss: 105953.6418; val_kl_reg_loss: 149.1053; val_edge_recon_loss: 78.8535; val_gene_expr_recon_loss: 100301.8047; val_lambda_latent_contrastive_instanceloss: 6.3441; val_lambda_latent_contrastive_clusterloss: 2.6144; val_gene_expr_mmd_loss: 10653.9302; val_global_loss: 111113.8047; val_optim_loss: 111113.8047
# Epoch 4/100 |--------------------| 4.0% val_auroc_score: 0.9722; val_auprc_score: 0.9646; val_best_acc_score: 0.8972; val_best_f1_score: 0.9060; train_kl_reg_loss: 177.9486; train_edge_recon_loss: 74.5786; train_gene_expr_recon_loss: 95348.5252; train_lambda_latent_contrastive_instanceloss: 6.4807; train_lambda_latent_contrastive_clusterloss: 2.7723; train_gene_expr_mmd_loss: 10888.3433; train_global_loss: 106424.0697; train_optim_loss: 106424.0697; val_kl_reg_loss: 144.1924; val_edge_recon_loss: 78.8632; val_gene_expr_recon_loss: 101175.3125; val_lambda_latent_contrastive_instanceloss: 6.3330; val_lambda_latent_contrastive_clusterloss: 2.6208; val_gene_expr_mmd_loss: 10935.8511; val_global_loss: 112264.3125; val_optim_loss: 112264.3125
# Epoch 5/100 |█-------------------| 5.0% val_auroc_score: 0.9757; val_auprc_score: 0.9695; val_best_acc_score: 0.9106; val_best_f1_score: 0.9172; train_kl_reg_loss: 178.4992; train_edge_recon_loss: 74.5186; train_gene_expr_recon_loss: 95083.1965; train_lambda_latent_contrastive_instanceloss: 6.4601; train_lambda_latent_contrastive_clusterloss: 2.7452; train_gene_expr_mmd_loss: 11559.8192; train_global_loss: 106830.7200; train_optim_loss: 106830.7200; val_kl_reg_loss: 135.3457; val_edge_recon_loss: 78.6868; val_gene_expr_recon_loss: 99746.7773; val_lambda_latent_contrastive_instanceloss: 6.3453; val_lambda_latent_contrastive_clusterloss: 2.6100; val_gene_expr_mmd_loss: 11800.8184; val_global_loss: 111691.8945; val_optim_loss: 111691.8945
# Epoch 6/100 |█-------------------| 6.0% val_auroc_score: 0.9743; val_auprc_score: 0.9678; val_best_acc_score: 0.9082; val_best_f1_score: 0.9150; train_kl_reg_loss: 167.3122; train_edge_recon_loss: 74.3695; train_gene_expr_recon_loss: 96811.3498; train_lambda_latent_contrastive_instanceloss: 6.4769; train_lambda_latent_contrastive_clusterloss: 2.7612; train_gene_expr_mmd_loss: 10249.3136; train_global_loss: 107237.2127; train_optim_loss: 107237.2127; val_kl_reg_loss: 137.9379; val_edge_recon_loss: 78.7145; val_gene_expr_recon_loss: 96356.8750; val_lambda_latent_contrastive_instanceloss: 6.3401; val_lambda_latent_contrastive_clusterloss: 2.6451; val_gene_expr_mmd_loss: 10631.7373; val_global_loss: 107135.5352; val_optim_loss: 107135.5352
# Epoch 7/100 |█-------------------| 7.0% val_auroc_score: 0.9719; val_auprc_score: 0.9638; val_best_acc_score: 0.9061; val_best_f1_score: 0.9131; train_kl_reg_loss: 176.4412; train_edge_recon_loss: 74.4042; train_gene_expr_recon_loss: 93619.2350; train_lambda_latent_contrastive_instanceloss: 6.4743; train_lambda_latent_contrastive_clusterloss: 2.7578; train_gene_expr_mmd_loss: 12869.8548; train_global_loss: 106674.7632; train_optim_loss: 106674.7632; val_kl_reg_loss: 135.0846; val_edge_recon_loss: 78.6907; val_gene_expr_recon_loss: 97781.1953; val_lambda_latent_contrastive_instanceloss: 6.3524; val_lambda_latent_contrastive_clusterloss: 2.6315; val_gene_expr_mmd_loss: 10499.5312; val_global_loss: 108424.7969; val_optim_loss: 108424.7969
# Epoch 8/100 |█-------------------| 8.0% val_auroc_score: 0.9735; val_auprc_score: 0.9660; val_best_acc_score: 0.9111; val_best_f1_score: 0.9176; train_kl_reg_loss: 169.9574; train_edge_recon_loss: 74.2343; train_gene_expr_recon_loss: 94871.4020; train_lambda_latent_contrastive_instanceloss: 6.4660; train_lambda_latent_contrastive_clusterloss: 2.7476; train_gene_expr_mmd_loss: 9405.3029; train_global_loss: 104455.8780; train_optim_loss: 104455.8780; val_kl_reg_loss: 139.3351; val_edge_recon_loss: 78.7826; val_gene_expr_recon_loss: 97806.4961; val_lambda_latent_contrastive_instanceloss: 6.3396; val_lambda_latent_contrastive_clusterloss: 2.6199; val_gene_expr_mmd_loss: 11498.0815; val_global_loss: 109452.8711; val_optim_loss: 109452.8711
# Epoch 9/100 |█-------------------| 9.0% val_auroc_score: 0.9742; val_auprc_score: 0.9658; val_best_acc_score: 0.8988; val_best_f1_score: 0.9074; train_kl_reg_loss: 177.4509; train_edge_recon_loss: 74.4101; train_gene_expr_recon_loss: 96175.3011; train_lambda_latent_contrastive_instanceloss: 6.4727; train_lambda_latent_contrastive_clusterloss: 2.7567; train_gene_expr_mmd_loss: 10440.1698; train_global_loss: 106802.1514; train_optim_loss: 106802.1514; val_kl_reg_loss: 149.3957; val_edge_recon_loss: 78.8673; val_gene_expr_recon_loss: 95170.7734; val_lambda_latent_contrastive_instanceloss: 6.3444; val_lambda_latent_contrastive_clusterloss: 2.6380; val_gene_expr_mmd_loss: 14317.9561; val_global_loss: 109647.1094; val_optim_loss: 109647.1094
# Epoch 10/100 |██------------------| 10.0% val_auroc_score: 0.9767; val_auprc_score: 0.9711; val_best_acc_score: 0.9033; val_best_f1_score: 0.9113; train_kl_reg_loss: 180.7579; train_edge_recon_loss: 74.4976; train_gene_expr_recon_loss: 93774.4014; train_lambda_latent_contrastive_instanceloss: 6.4642; train_lambda_latent_contrastive_clusterloss: 2.7483; train_gene_expr_mmd_loss: 9053.9895; train_global_loss: 103018.3642; train_optim_loss: 103018.3642; val_kl_reg_loss: 147.9350; val_edge_recon_loss: 78.8570; val_gene_expr_recon_loss: 95120.4141; val_lambda_latent_contrastive_instanceloss: 6.3580; val_lambda_latent_contrastive_clusterloss: 2.6358; val_gene_expr_mmd_loss: 13309.4111; val_global_loss: 108586.7500; val_optim_loss: 108586.7500
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 4 epochs.
# New learning rate is 0.0001.
#
# Epoch 11/100 |██------------------| 11.0% val_auroc_score: 0.9747; val_auprc_score: 0.9681; val_best_acc_score: 0.9040; val_best_f1_score: 0.9118; train_kl_reg_loss: 181.7852; train_edge_recon_loss: 74.4413; train_gene_expr_recon_loss: 94268.6947; train_lambda_latent_contrastive_instanceloss: 6.4602; train_lambda_latent_contrastive_clusterloss: 2.7465; train_gene_expr_mmd_loss: 10706.0486; train_global_loss: 105165.7356; train_optim_loss: 105165.7356; val_kl_reg_loss: 150.2084; val_edge_recon_loss: 78.8276; val_gene_expr_recon_loss: 92085.8086; val_lambda_latent_contrastive_instanceloss: 6.3318; val_lambda_latent_contrastive_clusterloss: 2.6087; val_gene_expr_mmd_loss: 12075.6562; val_global_loss: 104320.6172; val_optim_loss: 104320.6172
# Epoch 12/100 |██------------------| 12.0% val_auroc_score: 0.9717; val_auprc_score: 0.9633; val_best_acc_score: 0.8957; val_best_f1_score: 0.9048; train_kl_reg_loss: 181.8753; train_edge_recon_loss: 74.4470; train_gene_expr_recon_loss: 94765.7566; train_lambda_latent_contrastive_instanceloss: 6.4652; train_lambda_latent_contrastive_clusterloss: 2.7484; train_gene_expr_mmd_loss: 9391.1380; train_global_loss: 104347.9838; train_optim_loss: 104347.9838; val_kl_reg_loss: 149.7460; val_edge_recon_loss: 78.8203; val_gene_expr_recon_loss: 96957.6992; val_lambda_latent_contrastive_instanceloss: 6.3554; val_lambda_latent_contrastive_clusterloss: 2.6354; val_gene_expr_mmd_loss: 11780.8286; val_global_loss: 108897.2617; val_optim_loss: 108897.2617
# Epoch 13/100 |██------------------| 13.0% val_auroc_score: 0.9715; val_auprc_score: 0.9634; val_best_acc_score: 0.8993; val_best_f1_score: 0.9078; train_kl_reg_loss: 182.4788; train_edge_recon_loss: 74.4474; train_gene_expr_recon_loss: 94384.1611; train_lambda_latent_contrastive_instanceloss: 6.4581; train_lambda_latent_contrastive_clusterloss: 2.7501; train_gene_expr_mmd_loss: 10226.8679; train_global_loss: 104802.7157; train_optim_loss: 104802.7157; val_kl_reg_loss: 147.6583; val_edge_recon_loss: 78.7981; val_gene_expr_recon_loss: 95726.0273; val_lambda_latent_contrastive_instanceloss: 6.3557; val_lambda_latent_contrastive_clusterloss: 2.6485; val_gene_expr_mmd_loss: 14933.9580; val_global_loss: 110816.6445; val_optim_loss: 110816.6445
# Epoch 14/100 |██------------------| 14.0% val_auroc_score: 0.9742; val_auprc_score: 0.9665; val_best_acc_score: 0.9025; val_best_f1_score: 0.9104; train_kl_reg_loss: 179.9318; train_edge_recon_loss: 74.4167; train_gene_expr_recon_loss: 95332.2073; train_lambda_latent_contrastive_instanceloss: 6.4621; train_lambda_latent_contrastive_clusterloss: 2.7513; train_gene_expr_mmd_loss: 11257.0423; train_global_loss: 106778.3942; train_optim_loss: 106778.3942; val_kl_reg_loss: 149.8674; val_edge_recon_loss: 78.7690; val_gene_expr_recon_loss: 92946.2734; val_lambda_latent_contrastive_instanceloss: 6.3694; val_lambda_latent_contrastive_clusterloss: 2.6473; val_gene_expr_mmd_loss: 12196.3989; val_global_loss: 105301.5625; val_optim_loss: 105301.5625
# Epoch 15/100 |███-----------------| 15.0% val_auroc_score: 0.9719; val_auprc_score: 0.9633; val_best_acc_score: 0.8981; val_best_f1_score: 0.9068; train_kl_reg_loss: 183.8679; train_edge_recon_loss: 74.3820; train_gene_expr_recon_loss: 96471.3720; train_lambda_latent_contrastive_instanceloss: 6.4562; train_lambda_latent_contrastive_clusterloss: 2.7559; train_gene_expr_mmd_loss: 10528.7471; train_global_loss: 107193.2001; train_optim_loss: 107193.2001; val_kl_reg_loss: 150.0065; val_edge_recon_loss: 78.7817; val_gene_expr_recon_loss: 93122.0859; val_lambda_latent_contrastive_instanceloss: 6.3711; val_lambda_latent_contrastive_clusterloss: 2.6854; val_gene_expr_mmd_loss: 11522.7148; val_global_loss: 104803.8633; val_optim_loss: 104803.8633
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 4 epochs.
# New learning rate is 1e-05.
#
# Epoch 16/100 |███-----------------| 16.0% val_auroc_score: 0.9730; val_auprc_score: 0.9647; val_best_acc_score: 0.9040; val_best_f1_score: 0.9116; train_kl_reg_loss: 182.6489; train_edge_recon_loss: 74.4344; train_gene_expr_recon_loss: 92532.5397; train_lambda_latent_contrastive_instanceloss: 6.4619; train_lambda_latent_contrastive_clusterloss: 2.7529; train_gene_expr_mmd_loss: 10757.8150; train_global_loss: 103482.2169; train_optim_loss: 103482.2169; val_kl_reg_loss: 148.8351; val_edge_recon_loss: 78.7541; val_gene_expr_recon_loss: 95001.3594; val_lambda_latent_contrastive_instanceloss: 6.3449; val_lambda_latent_contrastive_clusterloss: 2.6315; val_gene_expr_mmd_loss: 11881.7241; val_global_loss: 107040.8867; val_optim_loss: 107040.8867
# Epoch 17/100 |███-----------------| 17.0% val_auroc_score: 0.9738; val_auprc_score: 0.9651; val_best_acc_score: 0.9030; val_best_f1_score: 0.9108; train_kl_reg_loss: 181.3051; train_edge_recon_loss: 74.4276; train_gene_expr_recon_loss: 93192.6665; train_lambda_latent_contrastive_instanceloss: 6.4540; train_lambda_latent_contrastive_clusterloss: 2.7446; train_gene_expr_mmd_loss: 10113.8015; train_global_loss: 103496.9712; train_optim_loss: 103496.9712; val_kl_reg_loss: 149.5540; val_edge_recon_loss: 78.7288; val_gene_expr_recon_loss: 90513.2188; val_lambda_latent_contrastive_instanceloss: 6.3485; val_lambda_latent_contrastive_clusterloss: 2.6430; val_gene_expr_mmd_loss: 13898.8726; val_global_loss: 104570.6289; val_optim_loss: 104570.6289
# Epoch 18/100 |███-----------------| 18.0% val_auroc_score: 0.9735; val_auprc_score: 0.9655; val_best_acc_score: 0.9024; val_best_f1_score: 0.9103; train_kl_reg_loss: 181.8931; train_edge_recon_loss: 74.4561; train_gene_expr_recon_loss: 93985.5805; train_lambda_latent_contrastive_instanceloss: 6.4559; train_lambda_latent_contrastive_clusterloss: 2.7476; train_gene_expr_mmd_loss: 9650.3405; train_global_loss: 103827.0156; train_optim_loss: 103827.0156; val_kl_reg_loss: 150.0296; val_edge_recon_loss: 78.8249; val_gene_expr_recon_loss: 94428.4609; val_lambda_latent_contrastive_instanceloss: 6.3561; val_lambda_latent_contrastive_clusterloss: 2.6268; val_gene_expr_mmd_loss: 15988.2822; val_global_loss: 110575.7539; val_optim_loss: 110575.7539
# Epoch 19/100 |███-----------------| 19.0% val_auroc_score: 0.9730; val_auprc_score: 0.9650; val_best_acc_score: 0.8987; val_best_f1_score: 0.9072; train_kl_reg_loss: 182.1744; train_edge_recon_loss: 74.4782; train_gene_expr_recon_loss: 95127.8834; train_lambda_latent_contrastive_instanceloss: 6.4496; train_lambda_latent_contrastive_clusterloss: 2.7303; train_gene_expr_mmd_loss: 10034.9651; train_global_loss: 105354.2031; train_optim_loss: 105354.2031; val_kl_reg_loss: 149.5223; val_edge_recon_loss: 78.7253; val_gene_expr_recon_loss: 98406.4688; val_lambda_latent_contrastive_instanceloss: 6.3388; val_lambda_latent_contrastive_clusterloss: 2.6234; val_gene_expr_mmd_loss: 11219.9263; val_global_loss: 109784.8828; val_optim_loss: 109784.8828
#
# Stopping early: metric has not improved more than 0.0 in the last 8 epochs.
# If the early stopping criterion is too strong, please instantiate it with different parameters in the train method.
# Model training finished after 1 min 30 sec.
# Using best model state, which was in epoch 11.
#
# --- MODEL EVALUATION ---
# val AUROC score: 0.9729
# val AUPRC score: 0.9642
# val best accuracy score: 0.9029
# val best F1 score: 0.9108
# val MSE score: 0.2937

# %%
# plot UMAP
sc.pp.neighbors(new_model.adata, use_rep='garfield_latent')
sc.tl.umap(new_model.adata)
sc.pl.umap(new_model.adata, color=['projection', 'celltype'],
           ncols=1, wspace=0.20, edges=False)

# %%
## split
adata_ref = new_model.adata[new_model.adata.obs['projection'] == 'reference', :]
adata_query = new_model.adata[new_model.adata.obs['projection'] == 'query', :]

# %% [markdown]
# ## Label transfer

# %%
### Label transfer
## major celltype
adata_query = new_model.label_transfer(ref_adata=adata_ref,
                                       ref_adata_emb='garfield_latent',
                                       query_adata=adata_query,
                                       query_adata_emb='garfield_latent',
                                       n_neighbors=10,
                                       ref_adata_obs=adata_ref.obs,
                                       label_keys='celltype')
adata_query
# Out:
# Weighted KNN with n_neighbors = 10 ...
# Label transfer finished!
# AnnData object with n_obs × n_vars = 4679 × 3000
#     obs: 'ClusterID', 'ClusterName', 'batch', 'celltype', 'nCount_RNA', 'n_genes', 'projection', 'transferred_celltype_unfiltered', 'transferred_celltype_uncert'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection', 'mean', 'std'
#     uns: 'log1p', 'hvg', 'pca', 'neighbors', 'umap', 'projection_colors', 'celltype_colors'
#     obsm: 'X_pca', 'X_umap', 'feat', 'garfield_latent', 'pca_cell_embeddings', 'umap_cell_embeddings'
#     varm: 'PCs'
#     layers: 'counts', 'norm_data', 'scale_data'
#     obsp: 'distances', 'connectivities'

# %%
## predicted label
sc.pl.umap(adata_query,color=['transferred_celltype_unfiltered'])

# %%
## real label
sc.pl.umap(adata_query,color=['celltype'])

# %%
import pandas as pd
pd.crosstab(adata_query.obs.celltype, adata_query.obs.transferred_celltype_unfiltered)
# Out:
# transferred_celltype_unfiltered  acinar  activated_stellate  alpha  beta  \
# celltype
# acinar                              461                   0      0     0
# activated_stellate                    0                 145      0     0
# alpha                                12                   6   1822    11
# beta                                  1                   0      2   746
# delta                                 0                   0      4     7
# ductal                                1                   0      2     2
# endothelial                           0                   0      0     0
# epsilon                               0                   0      2     1
# gamma                                 0                   0      5     0
# macrophage                            0                   0      0     0
# mast                                  0                   0      0     0
# quiescent_stellate                    0                   6      1     0
# schwann                               0                   0      0     0
#
# transferred_celltype_unfiltered  delta  ductal  endothelial  epsilon  gamma  \
# celltype
# acinar                               0       1            0        0      0
# activated_stellate                   0       0            0        0      0
# alpha                                1       0            0        0      0
# beta                                 3       1            0        0      0
# delta                              318       1            0        0      0
# ductal                               0     696            0        0      0
# endothelial                          0       0           42        0      0
# epsilon                              2       0            0        3      4
# gamma                                0       0            0        0    318
# macrophage                           0       0            0        0      0
# mast                                 0       1            0        0      0
# quiescent_stellate                   0       1            0        0      0
# schwann                              0       0            0        0      0
#
# transferred_celltype_unfiltered  macrophage  mast  quiescent_stellate  schwann
# celltype
# acinar                                    0     0                   0        0
# activated_stellate                        0     0                   0        0
# alpha                                     0     0                   0        0
# beta                                      0     0                   0        0
# delta                                     0     0                   0        0
# ductal                                    0     0                   0        0
# endothelial                               0     0                   0        0
# epsilon                                   0     0                   0        0
# gamma                                     0     0                   0        0
# macrophage                               21     1                   0        0
# mast                                      0    12                   0        0
# quiescent_stellate                        0     0                  10        0
# schwann                                   0     0                   0        6

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

cm = confusion_matrix(adata_query.obs.celltype, adata_query.obs.transferred_celltype_unfiltered)
ConfusionMatrixDisplay(
    confusion_matrix=np.round((cm.T/np.sum(cm, axis=1)).T*100),
    display_labels=np.unique(adata_query.obs.celltype)
).plot()

# %%
# Save trained model
model.save(dir_path=model_folder_path,
           overwrite=True,
           save_adata=True,
           adata_file_name="adata_concat.h5ad")
